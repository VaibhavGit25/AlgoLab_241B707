# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavGit25/AlgoLab_241B707/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
n = int(input("Enter the number of nodes: "))
dict1 = {}

for i in range(n):
    key1 = input("\nEnter a node: ")
    n1 = int(input(f"Enter the no of nodes connected to {key1}: "))

    dict2 = {}

    for j in range(n1):
        key2 = input("Enter the connected node: ")
        value2 = int(input("Enter the distance/value: "))
        dict2[key2] = value2

    dict1[key1] = dict2
sn=input("Enter source node: ")
print("\nFinal Dictionary:", dict1)

result = dijkstra(dict1, sn)

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Enter the number of nodes: 3
#
# Enter a node: A
# Enter the no of nodes connected to A: 2
# Enter the connected node: B
# Enter the distance/value: 4
# Enter the connected node: C
# Enter the distance/value: 2
#
# Enter a node: B
# Enter the no of nodes connected to B: 2
# Enter the connected node: A
# Enter the distance/value: 4
# Enter the connected node: C
# Enter the distance/value: 5
#
# Enter a node: C
# Enter the no of nodes connected to C: 2
# Enter the connected node: A
# Enter the distance/value: 2
# Enter the connected node: B
# Enter the distance/value: 5
# Enter source node: A
#
# Final Dictionary: {'A': {'B': 4, 'C': 2}, 'B': {'A': 4, 'C': 5}, 'C': {'A': 2, 'B': 5}}
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2

# %%
graph1 = {
'A': {'B': 2, 'C': 5},
'B': {'A': 1, 'C': 3, 'D': 7},
'C': {'A': 0, 'B': 4, 'D': 9, 'E':3},
'D': {'B': 12, 'C': 4, 'E': 2},
'E':{'C':6, 'D':4, 'F':1},
'F':{'E':3}
}

result = dijkstra(graph1, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 2
# Distance from A to C = 5
# Distance from A to D = 9
# Distance from A to E = 8
# Distance from A to F = 9

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def shortest_path(graph, start):
    distances = {node: float('inf') for node in graph}
    predecessors = {node: None for node in graph}
    visited = []
    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None: break
        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    print(f"Shortest paths starting from node '{start}':")
    print("-" * 40)
    for target in graph:
        path = []
        current = target
        while current is not None:
            path.append(current)
            current = predecessors[current]
        path.reverse()

        path_str = " -> ".join(path)
        dist = distances[target]
        print(f"Target: {target} | Distance: {dist} | Path: {path_str}")

graph1 = {
    'A': {'B': 2, 'C': 5},
    'B': {'A': 1, 'C': 3, 'D': 7},
    'C': {'A': 0, 'B': 4, 'D': 9, 'E': 3},
    'D': {'B': 12, 'C': 4, 'E': 2},
    'E': {'C': 6, 'D': 4, 'F': 1},
    'F': {'E': 3}
}

shortest_path(graph1, 'A')
# Out:
# Shortest paths starting from node 'A':
# ----------------------------------------
# Target: A | Distance: 0 | Path: A
# Target: B | Distance: 2 | Path: A -> B
# Target: C | Distance: 5 | Path: A -> C
# Target: D | Distance: 9 | Path: A -> B -> D
# Target: E | Distance: 8 | Path: A -> C -> E
# Target: F | Distance: 9 | Path: A -> C -> E -> F
